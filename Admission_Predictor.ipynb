# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/Admission_Predict_Ver1.1.csv')

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.shape
# Out:
# (500, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
# Check for duplicated rows and sum them
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Ensure this cell is executed to load the DataFrame
df = pd.read_csv('/content/Admission_Predict_Ver1.1.csv')

# Now execute the code to drop the column
# Drop the 'Serial No. ' column
df.drop(columns=['Serial No. '],inplace=True)

# Display the head to confirm the column is dropped
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-4b2dfbdc18d6> in <cell line: 0>()
#       4 # Now execute the code to drop the column
#       5 # Drop the 'Serial No. ' column
# ----> 6 df.drop(columns=['Serial No. '],inplace=True)
#       7
#       8 # Display the head to confirm the column is dropped
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# ...

# %%
# Ensure this cell is executed to load the DataFrame
df = pd.read_csv('/content/Admission_Predict_Ver1.1.csv')

# Get the exact column names from the DataFrame
column_names = df.columns

# Print the column names with their indices to help identify the 'Serial No.' column
# You can visually inspect this output to see the exact string
print("DataFrame Columns:")
for i, col in enumerate(column_names):
    print(f"Index {i}: '{col}'")

# Find the exact column name for 'Serial No.' in the list
# We'll assume it's the first column based on the usual structure,
# but you can adjust the index or use a loop to find it if it's elsewhere.
# Based on your previous code and the typical structure, it's likely the first column.
serial_no_col_name = column_names[0] # Get the exact string of the first column

# Now execute the code to drop the column using the exact name obtained
# Check if the column exists before dropping, for robustness
if serial_no_col_name in df.columns:
    print(f"Dropping column: '{serial_no_col_name}'")
    df.drop(columns=[serial_no_col_name], inplace=True)
    print(f"'{serial_no_col_name}' column dropped successfully.")
else:
    print(f"Column '{serial_no_col_name}' not found. It might have already been dropped.")


# Display the head to confirm the column is dropped
df.head()
# Out:
# DataFrame Columns:
# Index 0: 'Serial No.'
# Index 1: 'GRE Score'
# Index 2: 'TOEFL Score'
# Index 3: 'University Rating'
# Index 4: 'SOP'
# Index 5: 'LOR '
# Index 6: 'CGPA'
# Index 7: 'Research'
# Index 8: 'Chance of Admit '
# Dropping column: 'Serial No.'
# 'Serial No.' column dropped successfully.
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
X = df.iloc[:,0:-1]
y = df.iloc[:,-1]

# %%
X
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
# [500 rows x 7 columns]

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit , Length: 500, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 238        310          104                  3  2.0   3.5  8.37         0
# 438        318          110                  1  2.5   3.5  8.54         1
# 475        300          101                  3  3.5   2.5  7.88         0
# 58         300           99                  1  3.0   2.0  6.80         1
# 380        322          104                  3  3.5   4.0  8.84         1
# ..         ...          ...                ...  ...   ...   ...       ...
# 255        307          110                  4  4.0   4.5  8.37         0
# 72         321          111                  5  5.0   5.0  9.45         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 235        326          111                  5  4.5   4.0  9.23         1
# 37         300          105                  1  1.0   2.0  7.80         0
#
# [400 rows x 7 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
Scaler = MinMaxScaler()

X_train_Scaled = Scaler.fit_transform(X_train)
X_test_Scaled = Scaler.transform(X_test)

# %%
X_train_Scaled
# Out:
# array([[0.4       , 0.42857143, 0.5       , ..., 0.57142857, 0.50320513,
#         0.        ],
#        [0.56      , 0.64285714, 0.        , ..., 0.57142857, 0.55769231,
#         1.        ],
#        [0.2       , 0.32142857, 0.5       , ..., 0.28571429, 0.34615385,
#         0.        ],
#        ...,
#        [0.7       , 0.53571429, 0.5       , ..., 0.57142857, 0.74038462,
#         1.        ],
#        [0.72      , 0.67857143, 1.        , ..., 0.71428571, 0.77884615,
#         1.        ],
#        [0.2       , 0.46428571, 0.        , ..., 0.14285714, 0.32051282,
#         0.        ]])

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
# Ensure this cell is executed to import necessary modules
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# Ensure this cell is executed to define the model
model = Sequential()
model.add(Dense(7,activation = 'relu',input_dim = 7))
model.add(Dense(7,activation = 'relu'))
model.add(Dense(1,activation = 'linear'))

# Ensure this cell is executed to display the model summary
model.summary()

# Compile the model with the correct loss function name
# Changed 'mean_squared_loss' to 'mean_squared_error' or 'mse'
model.compile(loss='mean_squared_error',optimizer='Adam')

# Ensure this cell is executed to train the model
history = model.fit(X_train_Scaled,y_train,epochs=100,validation_split=0.2)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 7)              │            56 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 7)              │            56 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │             8 │
# ...

# %%
y_pred = model.predict(X_test_Scaled)
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e66d141af20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.7935101546414065

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
